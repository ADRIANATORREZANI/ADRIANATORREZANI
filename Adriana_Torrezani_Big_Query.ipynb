# %% [markdown]
# <a href="https://colab.research.google.com/github/ADRIANATORREZANI/ADRIANATORREZANI/blob/main/Adriana_Torrezani_Big_Query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-cloud-bigquery --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.9/247.9 kB 11.1 MB/s eta 0:00:00

# %%
from google.colab import auth
auth.authenticate_user()

# %%
def consulta():
    import re
    from google.cloud import bigquery

    # Configurações fixas
    project_id = "omega-signifier-454016-c4"
    dataset = "locadora"

    # Entrada do usuário
    sql = input("Digite sua query (sem project_id.dataset):\n")
    nome_df = input("Informe o nome para o DataFrame:\n")

    # Ajusta FROM e JOINs com project.dataset
    sql = re.sub(r"FROM\s+(\w+)", lambda m: f"FROM `{project_id}.{dataset}.{m.group(1)}`", sql, flags=re.I)
    sql = re.sub(r"(JOIN|LEFT JOIN|RIGHT JOIN|INNER JOIN|FULL JOIN|OUTER JOIN)\s+(\w+)",
                 lambda m: f"{m.group(1)} `{project_id}.{dataset}.{m.group(2)}`", sql, flags=re.I)
    print(sql)

    # Executa no BigQuery
    df = bigquery.Client(project=project_id).query(sql).to_dataframe()
    globals()[nome_df] = df

    print(f"\n✅ DataFrame '{nome_df}' criado com sucesso! ({len(df)} linhas)")
    display(df)

# %% [markdown]
# Exercícios
#
# Com base no banco de dados locadora,
#
# Elabore um arquivo do colab para responder os exercícios a seguir em consultas MySQL. Cada exercício deverá ser respondido em SQL, ao final você deverá entregar apenas o colab com as consultas.

# %%
'''1 - Selecione todos os dados da tabela cliente'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT * FROM cliente
# Informe o nome para o DataFrame:
# 2
# SELECT * FROM `omega-signifier-454016-c4.locadora.cliente`
#
# ✅ DataFrame '2' criado com sucesso! (5 linhas)
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %%
'''2 - Liste todos os clientes que moram na cidade de "São Paulo".'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT nome, estado FROM cliente WHERE estado = 'SP'
# Informe o nome para o DataFrame:
# 3
# SELECT nome, estado FROM `omega-signifier-454016-c4.locadora.cliente` WHERE estado = 'SP'
#
# ✅ DataFrame '3' criado com sucesso! (2 linhas)
#              nome estado
# 0  Fernando Souza     SP
# 1   Lúcia Andrade     SP

# %%
'''3 - Liste os estados diferentes presentes na tabela cliente.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT DISTINCT estado FROM cliente;
# Informe o nome para o DataFrame:
# 4
# SELECT DISTINCT estado FROM `omega-signifier-454016-c4.locadora.cliente`;
#
# ✅ DataFrame '4' criado com sucesso! (2 linhas)
#   estado
# 0     RJ
# 1     SP

# %%
'''4 - Liste todos os clientes ordenados pelo nome em ordem alfabética.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT nome FROM cliente ORDER BY nome;
# Informe o nome para o DataFrame:
# 5
# SELECT nome FROM `omega-signifier-454016-c4.locadora.cliente` ORDER BY nome;
#
# ✅ DataFrame '5' criado com sucesso! (5 linhas)
#                nome
# 0         Ana Silva
# 1     Bruna Pereira
# 2    Fernando Souza
# 3     Lúcia Andrade
# 4  Túlio Nascimento

# %%
'''5 - Encontre todos os clientes que são do sexo feminino e solteiros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT * FROM cliente WHERE sexo =   'F' AND estadocivil = 'S';
# Informe o nome para o DataFrame:
# 6
# SELECT * FROM `omega-signifier-454016-c4.locadora.cliente` WHERE sexo =   'F' AND estadocivil = 'S';
#
# ✅ DataFrame '6' criado com sucesso! (0 linhas)
# Empty DataFrame
# Columns: [codcliente, nome, cidade, sexo, estado, estadocivil]
# Index: []

# %%
'''6 - Liste todos os clientes cujo nome começa com a letra 'A'.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT nome FROM cliente WHERE nome LIKE 'A%'
# Informe o nome para o DataFrame:
# 7
# SELECT nome FROM `omega-signifier-454016-c4.locadora.cliente` WHERE nome LIKE 'A%'
#
# ✅ DataFrame '7' criado com sucesso! (1 linhas)
#         nome
# 0  Ana Silva

# %%
'''7 - Selecione os 3 primeiros registros da tabela cliente.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT * FROM cliente LIMIT 3;
# Informe o nome para o DataFrame:
# 8
# SELECT * FROM `omega-signifier-454016-c4.locadora.cliente` LIMIT 3;
#
# ✅ DataFrame '8' criado com sucesso! (3 linhas)
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %%
'''8 - Liste todos os carros que são da marca 'Ford' ou 'Fiat'.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT modelo FROM carro WHERE modelo = 'ford' OR modelo = 'fiat';
# Informe o nome para o DataFrame:
# 9
# SELECT modelo FROM `omega-signifier-454016-c4.locadora.carro` WHERE modelo = 'ford' OR modelo = 'fiat';
#
# ✅ DataFrame '9' criado com sucesso! (0 linhas)
# Empty DataFrame
# Columns: [modelo]
# Index: []

# %%
'''9 - Encontre todos os carros cujo valor está entre 100 e 150.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT * FROM carro WHERE valor BETWEEN 100 AND 150
# Informe o nome para o DataFrame:
# 10
# SELECT * FROM `omega-signifier-454016-c4.locadora.carro` WHERE valor BETWEEN 100 AND 150
#
# ✅ DataFrame '10' criado com sucesso! (4 linhas)
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka    100
# 1         5         5   Kwid    120
# 2         2         2   Argo    150
# 3         4         4   Polo    150

# %%
'''10 - Conte quantos aluguéis foram realizados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT COUNT(*) AS total_alugueis FROM aluguel;
# Informe o nome para o DataFrame:
# 11
# SELECT COUNT(*) AS total_alugueis FROM `omega-signifier-454016-c4.locadora.aluguel`;
#
# ✅ DataFrame '11' criado com sucesso! (1 linhas)
#    total_alugueis
# 0              10

# %%
'''11 - Calcule o valor total de todos os carros disponíveis para aluguel.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT SUM(valor) FROM carro;
# Informe o nome para o DataFrame:
# 12
# SELECT SUM(valor) FROM `omega-signifier-454016-c4.locadora.carro`;
#
# ✅ DataFrame '12' criado com sucesso! (1 linhas)
#    f0_
# 0  690

# %%
'''12 - Calcule o valor médio dos carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT AVG(valor) AS media_valor_carros FROM carro;
# Informe o nome para o DataFrame:
# 13
# SELECT AVG(valor) AS media_valor_carros FROM `omega-signifier-454016-c4.locadora.carro`;
#
# ✅ DataFrame '13' criado com sucesso! (1 linhas)
#    media_valor_carros
# 0               138.0

# %%
'''13 - Encontre o menor e o maior valor de aluguel de carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT MIN(valor) AS menor_valor, MAX(valor) AS maior_valor FROM carro;
# Informe o nome para o DataFrame:
# 14
# SELECT MIN(valor) AS menor_valor, MAX(valor) AS maior_valor FROM `omega-signifier-454016-c4.locadora.carro`;
#
# ✅ DataFrame '14' criado com sucesso! (1 linhas)
#    menor_valor  maior_valor
# 0          100          170

# %%
'''14 - Agrupe os clientes por estado e conte quantos clientes existem em cada estado.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT estado, COUNT(codcliente) AS total_clientes FROM cliente GROUP BY estado;
# Informe o nome para o DataFrame:
# 15
# SELECT estado, COUNT(codcliente) AS total_clientes FROM `omega-signifier-454016-c4.locadora.cliente` GROUP BY estado;
#
# ✅ DataFrame '15' criado com sucesso! (2 linhas)
#   estado  total_clientes
# 0     RJ               3
# 1     SP               2

# %%
'''15 - Agrupe os aluguéis por cliente e filtre apenas aqueles que fizeram mais de 2 aluguéis.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT codcliente, COUNT(*) AS total_alugueis FROM aluguel GROUP BY codcliente HAVING COUNT(*) > 2;
# Informe o nome para o DataFrame:
# 16
# SELECT codcliente, COUNT(*) AS total_alugueis FROM `omega-signifier-454016-c4.locadora.aluguel` GROUP BY codcliente HAVING COUNT(*) > 2;
#
# ✅ DataFrame '16' criado com sucesso! (2 linhas)
#    codcliente  total_alugueis
# 0           2               3
# 1           1               3

# %%
'''16 - Liste todos os aluguéis, mostrando o nome do cliente e o modelo do carro alugado.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT codaluguel, data_aluguel FROM aluguel;
# Informe o nome para o DataFrame:
# 17
# SELECT codaluguel, data_aluguel FROM `omega-signifier-454016-c4.locadora.aluguel`;
#
# ✅ DataFrame '17' criado com sucesso! (10 linhas)
#    codaluguel data_aluguel
# 0           2   2023-04-02
# 1           3   2023-04-03
# 2           7   2023-04-15
# 3          10   2023-04-25
# 4           1   2023-04-01
# 5           8   2023-04-19
# 6           9   2023-04-21
# 7           4   2023-04-04
# 8           5   2023-04-05
# 9           6   2023-04-13

# %%
'''17 - Liste todos os carros e, se houver, as informações sobre os aluguéis realizados desses carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT      c.codcarro,     c.modelo,     c.valor,     a.codaluguel,     a.codcliente,     a.data_aluguel FROM carro c LEFT JOIN aluguel a ON c.codcarro = a.codcarro;
# Informe o nome para o DataFrame:
# 18
# SELECT      c.codcarro,     c.modelo,     c.valor,     a.codaluguel,     a.codcliente,     a.data_aluguel FROM `omega-signifier-454016-c4.locadora.carro` c LEFT JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcarro = a.codcarro;
#
# ✅ DataFrame '18' criado com sucesso! (11 linhas)
#     codcarro modelo  valor  codaluguel  codcliente data_aluguel
# 0          1     Ka    100           2           2   2023-04-02
# 1          1     Ka    100           3           2   2023-04-03
# 2          1     Ka    100           7           1   2023-04-15
# 3          1     Ka    100          10           3   2023-04-25
# 4          5   Kwid    120        <NA>        <NA>          NaT
# 5          2   Argo    150           1           3   2023-04-01
# 6          2   Argo    150           8           5   2023-04-19
# 7          2   Argo    150           9           5   2023-04-21
# 8          4   Polo    150           5           1   2023-04-05
# 9          4   Polo    150           6           1   2023-04-13
# 10         3   Onix    170           4           2   2023-04-04

# %%
'''18 - Liste todos os aluguéis e as informações sobre os carros alugados, mesmo que o carro não esteja mais no banco de dados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT      a.codaluguel,     a.codcliente,     a.codcarro,     a.data_aluguel,     c.modelo,     c.valor FROM aluguel a LEFT JOIN carro c ON a.codcarro = c.codcarro;
# Informe o nome para o DataFrame:
# 19
# SELECT      a.codaluguel,     a.codcliente,     a.codcarro,     a.data_aluguel,     c.modelo,     c.valor FROM `omega-signifier-454016-c4.locadora.aluguel` a LEFT JOIN `omega-signifier-454016-c4.locadora.carro` c ON a.codcarro = c.codcarro;
#
# ✅ DataFrame '19' criado com sucesso! (10 linhas)
#    codaluguel  codcliente  codcarro data_aluguel modelo  valor
# 0           2           2         1   2023-04-02     Ka    100
# 1           3           2         1   2023-04-03     Ka    100
# 2           7           1         1   2023-04-15     Ka    100
# 3          10           3         1   2023-04-25     Ka    100
# 4           1           3         2   2023-04-01   Argo    150
# 5           8           5         2   2023-04-19   Argo    150
# 6           9           5         2   2023-04-21   Argo    150
# 7           4           2         3   2023-04-04   Onix    170
# 8           5           1         4   2023-04-05   Polo    150
# 9           6           1         4   2023-04-13   Polo    150

# %%
'''19 - Liste todos os clientes e os carros que alugaram, incluindo clientes que não alugaram e carros que não foram alugados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT      a.codaluguel,     a.codcliente,     a.codcarro,     a.data_aluguel,     c.modelo,     c.valor FROM aluguel a LEFT JOIN carro c ON a.codcarro = c.codcarro;
# Informe o nome para o DataFrame:
# 20
# SELECT      a.codaluguel,     a.codcliente,     a.codcarro,     a.data_aluguel,     c.modelo,     c.valor FROM `omega-signifier-454016-c4.locadora.aluguel` a LEFT JOIN `omega-signifier-454016-c4.locadora.carro` c ON a.codcarro = c.codcarro;
#
# ✅ DataFrame '20' criado com sucesso! (10 linhas)
#    codaluguel  codcliente  codcarro data_aluguel modelo  valor
# 0           2           2         1   2023-04-02     Ka    100
# 1           3           2         1   2023-04-03     Ka    100
# 2           7           1         1   2023-04-15     Ka    100
# 3          10           3         1   2023-04-25     Ka    100
# 4           1           3         2   2023-04-01   Argo    150
# 5           8           5         2   2023-04-19   Argo    150
# 6           9           5         2   2023-04-21   Argo    150
# 7           4           2         3   2023-04-04   Onix    170
# 8           5           1         4   2023-04-05   Polo    150
# 9           6           1         4   2023-04-13   Polo    150

# %%
'''20 - Combine os resultados de duas consultas: uma que lista clientes solteiros e outra que lista clientes casados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT nome, estadocivil,   CASE estadocivil     WHEN 'C' THEN 'Casado(a)'     WHEN 'S' THEN 'Solteiro(a)'     ELSE 'Outro'   END AS estado_civil_descricao FROM cliente;
# Informe o nome para o DataFrame:
# 21
# SELECT nome, estadocivil,   CASE estadocivil     WHEN 'C' THEN 'Casado(a)'     WHEN 'S' THEN 'Solteiro(a)'     ELSE 'Outro'   END AS estado_civil_descricao FROM `omega-signifier-454016-c4.locadora.cliente`;
#
# ✅ DataFrame '21' criado com sucesso! (5 linhas)
#                nome estadocivil estado_civil_descricao
# 0         Ana Silva           C              Casado(a)
# 1     Bruna Pereira           C              Casado(a)
# 2  Túlio Nascimento           S            Solteiro(a)
# 3    Fernando Souza           S            Solteiro(a)
# 4     Lúcia Andrade           C              Casado(a)

# %%
'''21 - Encontre os clientes que alugaram o carro com modelo 'Onix'.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, m.marca FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente JOIN carro ca ON a.codcarro = ca.codcarro JOIN marca m ON ca.codmarca = m.codmarca WHERE modelo = 'Onix';
# Informe o nome para o DataFrame:
# 22
# SELECT c.nome, m.marca FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` m ON ca.codmarca = m.codmarca WHERE modelo = 'Onix';
#
# ✅ DataFrame '22' criado com sucesso! (1 linhas)
#             nome      marca
# 0  Bruna Pereira  Chevrolet

# %%
'''22 - Liste os modelos de carros e o número de vezes que cada um foi alugado.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT modelo, COUNT (codmarca) AS total_alugueis FROM carro GROUP BY modelo;
# Informe o nome para o DataFrame:
# 23
# SELECT modelo, COUNT (codmarca) AS total_alugueis FROM `omega-signifier-454016-c4.locadora.carro` GROUP BY modelo;
#
# ✅ DataFrame '23' criado com sucesso! (5 linhas)
#   modelo  total_alugueis
# 0     Ka               1
# 1   Kwid               1
# 2   Argo               1
# 3   Polo               1
# 4   Onix               1

# %%
'''23 - Liste o nome dos clientes e o número de aluguéis que cada um fez.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, m.marca FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente JOIN carro ca ON a.codcarro = ca.codcarro JOIN marca m ON ca.codmarca = m.codmarca;
# Informe o nome para o DataFrame:
# 24
# SELECT c.nome, m.marca FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` m ON ca.codmarca = m.codmarca;
#
# ✅ DataFrame '24' criado com sucesso! (10 linhas)
#                nome       marca
# 0     Bruna Pereira        Ford
# 1     Bruna Pereira        Ford
# 2         Ana Silva        Ford
# 3  Túlio Nascimento        Ford
# 4  Túlio Nascimento        Fiat
# 5     Lúcia Andrade        Fiat
# 6     Lúcia Andrade        Fiat
# 7     Bruna Pereira   Chevrolet
# 8         Ana Silva  Volkswagen
# 9         Ana Silva  Volkswagen

# %%
'''24 - Crie uma consulta que retorne o nome dos clientes e uma coluna adicional chamada status_civil que classifica os clientes como "Solteiro" ou "Casado".'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT nome, estadocivil,   CASE estadocivil     WHEN 'C' THEN 'Casado(a)'     WHEN 'S' THEN 'Solteiro(a)'     ELSE 'Outro'   END AS estado_civil_descricao FROM cliente;
# Informe o nome para o DataFrame:
# 25
# SELECT nome, estadocivil,   CASE estadocivil     WHEN 'C' THEN 'Casado(a)'     WHEN 'S' THEN 'Solteiro(a)'     ELSE 'Outro'   END AS estado_civil_descricao FROM `omega-signifier-454016-c4.locadora.cliente`;
#
# ✅ DataFrame '25' criado com sucesso! (5 linhas)
#                nome estadocivil estado_civil_descricao
# 0         Ana Silva           C              Casado(a)
# 1     Bruna Pereira           C              Casado(a)
# 2  Túlio Nascimento           S            Solteiro(a)
# 3    Fernando Souza           S            Solteiro(a)
# 4     Lúcia Andrade           C              Casado(a)

# %%
'''25 - Liste os nomes dos clientes e as datas em que alugaram carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
#  SELECT c.nome, ca.modelo, a.data_aluguel FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente JOIN carro ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 26
#  SELECT c.nome, ca.modelo, a.data_aluguel FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '26' criado com sucesso! (10 linhas)
#                nome modelo data_aluguel
# 0     Bruna Pereira     Ka   2023-04-02
# 1     Bruna Pereira     Ka   2023-04-03
# 2         Ana Silva     Ka   2023-04-15
# 3  Túlio Nascimento     Ka   2023-04-25
# 4  Túlio Nascimento   Argo   2023-04-01
# 5     Lúcia Andrade   Argo   2023-04-19
# 6     Lúcia Andrade   Argo   2023-04-21
# 7     Bruna Pereira   Onix   2023-04-04
# 8         Ana Silva   Polo   2023-04-05
# 9         Ana Silva   Polo   2023-04-13

# %%
'''26 - Liste todos os modelos de carros e suas respectivas marcas.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT modelo, COUNT(codmarca) AS total_carros FROM carro GROUP BY modelo;
# Informe o nome para o DataFrame:
# 27
# SELECT modelo, COUNT(codmarca) AS total_carros FROM `omega-signifier-454016-c4.locadora.carro` GROUP BY modelo;
#
# ✅ DataFrame '27' criado com sucesso! (5 linhas)
#   modelo  total_carros
# 0     Ka             1
# 1   Kwid             1
# 2   Argo             1
# 3   Polo             1
# 4   Onix             1

# %%
'''27 - Liste todos os aluguéis e os nomes dos clientes que os realizaram.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, COUNT(a.codcliente) AS total_alugueis FROM cliente c JOIN aluguel a ON c.codcliente = a.codcliente GROUP BY c.nome;
# Informe o nome para o DataFrame:
# 28
# SELECT c.nome, COUNT(a.codcliente) AS total_alugueis FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente GROUP BY c.nome;
#
# ✅ DataFrame '28' criado com sucesso! (4 linhas)
#                nome  total_alugueis
# 0         Ana Silva               3
# 1     Bruna Pereira               3
# 2  Túlio Nascimento               2
# 3     Lúcia Andrade               2

# %%
'''28 - Encontre o nome dos clientes e os modelos de carros que alugaram.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, ca.modelo FROM aluguel AS a JOIN cliente AS c ON a.codcliente = c.codcliente JOIN carro AS ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 29
# SELECT c.nome, ca.modelo FROM `omega-signifier-454016-c4.locadora.aluguel` AS a JOIN `omega-signifier-454016-c4.locadora.cliente` AS c ON a.codcliente = c.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` AS ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '29' criado com sucesso! (10 linhas)
#                nome modelo
# 0     Bruna Pereira     Ka
# 1     Bruna Pereira     Ka
# 2         Ana Silva     Ka
# 3  Túlio Nascimento     Ka
# 4  Túlio Nascimento   Argo
# 5     Lúcia Andrade   Argo
# 6     Lúcia Andrade   Argo
# 7     Bruna Pereira   Onix
# 8         Ana Silva   Polo
# 9         Ana Silva   Polo

# %%
'''29 - Liste todos os carros e, se houver, mostre as datas em que foram alugados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, ca.modelo, a.data_aluguel FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente JOIN carro ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 30
# SELECT c.nome, ca.modelo, a.data_aluguel FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '30' criado com sucesso! (10 linhas)
#                nome modelo data_aluguel
# 0         Ana Silva     Ka   2023-04-15
# 1         Ana Silva   Polo   2023-04-05
# 2         Ana Silva   Polo   2023-04-13
# 3     Bruna Pereira     Ka   2023-04-02
# 4     Bruna Pereira     Ka   2023-04-03
# 5     Bruna Pereira   Onix   2023-04-04
# 6  Túlio Nascimento     Ka   2023-04-25
# 7  Túlio Nascimento   Argo   2023-04-01
# 8     Lúcia Andrade   Argo   2023-04-19
# 9     Lúcia Andrade   Argo   2023-04-21

# %%
'''30 - Encontre os clientes que moram na mesma cidade e estado e que alugaram carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c1.nome, c1.cidade, c1.estado FROM cliente c1 JOIN aluguel a ON c1.codcliente = a.codcliente WHERE EXISTS (     SELECT 1     FROM cliente c2     WHERE c1.cidade = c2.cidade AND c1.estado = c2.estado AND c1.codcliente <> c2.codcliente );
# Informe o nome para o DataFrame:
# 31
# SELECT c1.nome, c1.cidade, c1.estado FROM `omega-signifier-454016-c4.locadora.cliente` c1 JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c1.codcliente = a.codcliente WHERE EXISTS (     SELECT 1     FROM `omega-signifier-454016-c4.locadora.cliente` c2     WHERE c1.cidade = c2.cidade AND c1.estado = c2.estado AND c1.codcliente <> c2.codcliente );
#
# ✅ DataFrame '31' criado com sucesso! (5 linhas)
#                nome           cidade estado
# 0         Ana Silva  Duque de Caxias     RJ
# 1         Ana Silva  Duque de Caxias     RJ
# 2         Ana Silva  Duque de Caxias     RJ
# 3  Túlio Nascimento  Duque de Caxias     RJ
# 4  Túlio Nascimento  Duque de Caxias     RJ

# %%
''' 31 - Liste os nomes dos clientes e os carros que eles alugaram, incluindo os clientes que não alugaram nenhum carro.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS NomeCliente,     ca.modelo AS ModeloCarro FROM     cliente c LEFT JOIN     aluguel a ON c.codcliente = a.codcliente LEFT JOIN     carro ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 32
# SELECT     c.nome AS NomeCliente,     ca.modelo AS ModeloCarro FROM `omega-signifier-454016-c4.locadora.cliente` c LEFT JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente LEFT JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '32' criado com sucesso! (11 linhas)
#          NomeCliente ModeloCarro
# 0          Ana Silva          Ka
# 1          Ana Silva        Polo
# 2          Ana Silva        Polo
# 3      Bruna Pereira          Ka
# 4      Bruna Pereira          Ka
# 5      Bruna Pereira        Onix
# 6   Túlio Nascimento          Ka
# 7   Túlio Nascimento        Argo
# 8     Fernando Souza        None
# 9      Lúcia Andrade        Argo
# 10     Lúcia Andrade        Argo

# %%
'''32 - Liste todas as marcas e, se houver, os modelos de carros associados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     m.marca,     c.modelo FROM     marca m LEFT JOIN     carro c ON m.codmarca = c.codmarca;
# Informe o nome para o DataFrame:
# 33
# SELECT     m.marca,     c.modelo FROM `omega-signifier-454016-c4.locadora.marca` m LEFT JOIN `omega-signifier-454016-c4.locadora.carro` c ON m.codmarca = c.codmarca;
#
# ✅ DataFrame '33' criado com sucesso! (5 linhas)
#         marca modelo
# 0        Ford     Ka
# 1        Fiat   Argo
# 2   Chevrolet   Onix
# 3  Volkswagen   Polo
# 4     Renault   Kwid

# %%
'''33 - Encontre todos os aluguéis e o estado civil dos clientes que alugaram os carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT a.codaluguel, c.estadocivil FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente;
# Informe o nome para o DataFrame:
# 34
# SELECT a.codaluguel, c.estadocivil FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente;
#
# ✅ DataFrame '34' criado com sucesso! (10 linhas)
#    codaluguel estadocivil
# 0           2           C
# 1           3           C
# 2           7           C
# 3          10           S
# 4           1           S
# 5           8           C
# 6           9           C
# 7           4           C
# 8           5           C
# 9           6           C

# %%
'''34 - Liste os clientes e as cidades em que moram para aqueles que alugaram carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, c.cidade FROM cliente c JOIN aluguel a ON c.codcliente = a.codcliente;
# Informe o nome para o DataFrame:
# 35
# SELECT c.nome, c.cidade FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente;
#
# ✅ DataFrame '35' criado com sucesso! (10 linhas)
#                nome           cidade
# 0         Ana Silva  Duque de Caxias
# 1         Ana Silva  Duque de Caxias
# 2         Ana Silva  Duque de Caxias
# 3     Bruna Pereira          Niterói
# 4     Bruna Pereira          Niterói
# 5     Bruna Pereira          Niterói
# 6  Túlio Nascimento  Duque de Caxias
# 7  Túlio Nascimento  Duque de Caxias
# 8     Lúcia Andrade        São Paulo
# 9     Lúcia Andrade        São Paulo

# %%
'''35 - Liste os clientes que alugaram carros e os modelos de carros que eles alugaram, incluindo a marca do carro.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS NomeCliente,     ca.modelo AS ModeloCarro,     m.marca AS MarcaCarro FROM     cliente c JOIN     aluguel a ON c.codcliente = a.codcliente JOIN     carro ca ON a.codcarro = ca.codcarro JOIN     marca m ON ca.codmarca = m.codmarca;
# Informe o nome para o DataFrame:
# 36
# SELECT     c.nome AS NomeCliente,     ca.modelo AS ModeloCarro,     m.marca AS MarcaCarro FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` m ON ca.codmarca = m.codmarca;
#
# ✅ DataFrame '36' criado com sucesso! (10 linhas)
#         NomeCliente ModeloCarro  MarcaCarro
# 0         Ana Silva          Ka        Ford
# 1         Ana Silva        Polo  Volkswagen
# 2         Ana Silva        Polo  Volkswagen
# 3     Bruna Pereira          Ka        Ford
# 4     Bruna Pereira          Ka        Ford
# 5     Bruna Pereira        Onix   Chevrolet
# 6  Túlio Nascimento          Ka        Ford
# 7  Túlio Nascimento        Argo        Fiat
# 8     Lúcia Andrade        Argo        Fiat
# 9     Lúcia Andrade        Argo        Fiat

# %%
'''36 - Encontre todos os aluguéis realizados em uma cidade específica e liste os nomes dos clientes e os modelos de carros alugados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS nome_cliente,     ca.modelo AS modelo_carro FROM     cliente c JOIN     aluguel a ON c.codcliente = a.codcliente JOIN     carro ca ON a.codcarro = ca.codcarro WHERE     c.cidade = 'Duque de Caxias';
# Informe o nome para o DataFrame:
# 37
# SELECT     c.nome AS nome_cliente,     ca.modelo AS modelo_carro FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro WHERE     c.cidade = 'Duque de Caxias';
#
# ✅ DataFrame '37' criado com sucesso! (5 linhas)
#        nome_cliente modelo_carro
# 0         Ana Silva           Ka
# 1         Ana Silva         Polo
# 2         Ana Silva         Polo
# 3  Túlio Nascimento           Ka
# 4  Túlio Nascimento         Argo

# %%
'''37 - Liste os modelos de carros e a quantidade de vezes que foram alugados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.modelo, COUNT(a.codaluguel) AS quantidade_alugueis FROM carro c JOIN aluguel a ON c.codcarro = a.codcarro GROUP BY c.modelo;
# Informe o nome para o DataFrame:
# 38
# SELECT c.modelo, COUNT(a.codaluguel) AS quantidade_alugueis FROM `omega-signifier-454016-c4.locadora.carro` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcarro = a.codcarro GROUP BY c.modelo;
#
# ✅ DataFrame '38' criado com sucesso! (4 linhas)
#   modelo  quantidade_alugueis
# 0     Ka                    4
# 1   Argo                    3
# 2   Polo                    2
# 3   Onix                    1

# %%
'''38 - Encontre os clientes que alugaram mais de um carro.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT codcliente FROM aluguel GROUP BY codcliente HAVING COUNT(*) > 1;
# Informe o nome para o DataFrame:
# 39
# SELECT codcliente FROM `omega-signifier-454016-c4.locadora.aluguel` GROUP BY codcliente HAVING COUNT(*) > 1;
#
# ✅ DataFrame '39' criado com sucesso! (4 linhas)
#    codcliente
# 0           2
# 1           1
# 2           3
# 3           5

# %%
'''39 - Liste os clientes, as datas de aluguel e o valor do carro alugado.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS Cliente,     a.data_aluguel AS DataAluguel,     ca.valor AS ValorCarro FROM     cliente c JOIN     aluguel a ON c.codcliente = a.codcliente JOIN     carro ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 40
# SELECT     c.nome AS Cliente,     a.data_aluguel AS DataAluguel,     ca.valor AS ValorCarro FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '40' criado com sucesso! (10 linhas)
#             Cliente DataAluguel  ValorCarro
# 0         Ana Silva  2023-04-15         100
# 1         Ana Silva  2023-04-05         150
# 2         Ana Silva  2023-04-13         150
# 3     Bruna Pereira  2023-04-02         100
# 4     Bruna Pereira  2023-04-03         100
# 5     Bruna Pereira  2023-04-04         170
# 6  Túlio Nascimento  2023-04-25         100
# 7  Túlio Nascimento  2023-04-01         150
# 8     Lúcia Andrade  2023-04-19         150
# 9     Lúcia Andrade  2023-04-21         150

# %%
'''40 - Liste os modelos de carros que nunca foram alugados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.modelo FROM carro c LEFT JOIN aluguel a ON c.codcarro = a.codcarro WHERE a.codaluguel IS NULL;
# Informe o nome para o DataFrame:
# 41
# SELECT c.modelo FROM `omega-signifier-454016-c4.locadora.carro` c LEFT JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcarro = a.codcarro WHERE a.codaluguel IS NULL;
#
# ✅ DataFrame '41' criado com sucesso! (1 linhas)
#   modelo
# 0   Kwid

# %%
'''41 - Encontre os clientes que alugaram carros e o total gasto em aluguéis.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome AS nome_cliente, SUM(ca.valor) AS total_gasto FROM cliente c JOIN aluguel a ON c.codcliente = a.codcliente JOIN carro ca ON a.codcarro = ca.codcarro GROUP BY c.nome;
# Informe o nome para o DataFrame:
# 42
# SELECT c.nome AS nome_cliente, SUM(ca.valor) AS total_gasto FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro GROUP BY c.nome;
#
# ✅ DataFrame '42' criado com sucesso! (4 linhas)
#        nome_cliente  total_gasto
# 0         Ana Silva          400
# 1     Bruna Pereira          370
# 2  Túlio Nascimento          250
# 3     Lúcia Andrade          300

# %%
'''42 - Liste as marcas de carros e o número total de aluguéis por marca.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT   m.marca,   COUNT(a.codaluguel) AS total_alugueis FROM   aluguel AS a JOIN   carro AS c ON a.codcarro = c.codcarro JOIN   marca AS m ON c.codmarca = m.codmarca GROUP BY   m.marca;
# Informe o nome para o DataFrame:
# 43
# SELECT   m.marca,   COUNT(a.codaluguel) AS total_alugueis FROM `omega-signifier-454016-c4.locadora.aluguel` AS a JOIN `omega-signifier-454016-c4.locadora.carro` AS c ON a.codcarro = c.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` AS m ON c.codmarca = m.codmarca GROUP BY   m.marca;
#
# ✅ DataFrame '43' criado com sucesso! (4 linhas)
#         marca  total_alugueis
# 0        Ford               4
# 1        Fiat               3
# 2   Chevrolet               1
# 3  Volkswagen               2

# %%
'''43 - Encontre os clientes que alugaram carros em um determinado mês e ano, listando os modelos de carros e as datas de aluguel.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
#  SELECT codaluguel, data_aluguel FROM aluguel WHERE data_aluguel BETWEEN '2023-04-01' AND '2023-04-10';
# Informe o nome para o DataFrame:
# 44
#  SELECT codaluguel, data_aluguel FROM `omega-signifier-454016-c4.locadora.aluguel` WHERE data_aluguel BETWEEN '2023-04-01' AND '2023-04-10';
#
# ✅ DataFrame '44' criado com sucesso! (5 linhas)
#    codaluguel data_aluguel
# 0           2   2023-04-02
# 1           3   2023-04-03
# 2           1   2023-04-01
# 3           4   2023-04-04
# 4           5   2023-04-05

# %%
'''44 - Liste os clientes que moram em estados diferentes e que alugaram carros, junto com os modelos alugados.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, c.estado, ca.modelo FROM cliente c JOIN aluguel a ON c.codcliente = a.codcliente JOIN carro ca ON a.codcarro = ca.codcarro WHERE c.estado NOT IN (SELECT estado FROM cliente GROUP BY estado HAVING COUNT(*) = 1) GROUP BY c.nome, c.estado, ca.modelo;
# Informe o nome para o DataFrame:
# 45
# SELECT c.nome, c.estado, ca.modelo FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro WHERE c.estado NOT IN (SELECT estado FROM `omega-signifier-454016-c4.locadora.cliente` GROUP BY estado HAVING COUNT(*) = 1) GROUP BY c.nome, c.estado, ca.modelo;
#
# ✅ DataFrame '45' criado com sucesso! (7 linhas)
#                nome estado modelo
# 0         Ana Silva     RJ     Ka
# 1         Ana Silva     RJ   Polo
# 2     Bruna Pereira     RJ     Ka
# 3     Bruna Pereira     RJ   Onix
# 4  Túlio Nascimento     RJ     Ka
# 5  Túlio Nascimento     RJ   Argo
# 6     Lúcia Andrade     SP   Argo

# %%
'''45 - Encontre os clientes que alugaram carros, os modelos de carros alugados, as marcas desses carros e as datas de aluguel, ordenando pelos nomes dos clientes.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS nome_cliente,     ca.modelo AS modelo_carro,     m.marca AS marca_carro,     a.data_aluguel AS data_aluguel FROM     cliente c JOIN     aluguel a ON c.codcliente = a.codcliente JOIN     carro ca ON a.codcarro = ca.codcarro JOIN     marca m ON ca.codmarca = m.codmarca ORDER BY     c.nome;
# Informe o nome para o DataFrame:
# 46
# SELECT     c.nome AS nome_cliente,     ca.modelo AS modelo_carro,     m.marca AS marca_carro,     a.data_aluguel AS data_aluguel FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` m ON ca.codmarca = m.codmarca ORDER BY     c.nome;
#
# ✅ DataFrame '46' criado com sucesso! (10 linhas)
#        nome_cliente modelo_carro marca_carro data_aluguel
# 0         Ana Silva           Ka        Ford   2023-04-15
# 1         Ana Silva         Polo  Volkswagen   2023-04-05
# 2         Ana Silva         Polo  Volkswagen   2023-04-13
# 3     Bruna Pereira           Ka        Ford   2023-04-02
# 4     Bruna Pereira           Ka        Ford   2023-04-03
# 5     Bruna Pereira         Onix   Chevrolet   2023-04-04
# 6     Lúcia Andrade         Argo        Fiat   2023-04-19
# 7     Lúcia Andrade         Argo        Fiat   2023-04-21
# 8  Túlio Nascimento           Ka        Ford   2023-04-25
# 9  Túlio Nascimento         Argo        Fiat   2023-04-01

# %%
'''46 - Liste os clientes que alugaram carros mais de uma vez e os detalhes dos carros que alugaram.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome AS NomeCliente, ca.modelo AS ModeloCarro, ca.valor AS ValorCarro FROM cliente c JOIN aluguel a ON c.codcliente = a.codcliente JOIN carro ca ON a.codcarro = ca.codcarro GROUP BY c.nome, ca.modelo, ca.valor HAVING COUNT(a.codaluguel) > 1;
# Informe o nome para o DataFrame:
# 47
# SELECT c.nome AS NomeCliente, ca.modelo AS ModeloCarro, ca.valor AS ValorCarro FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro GROUP BY c.nome, ca.modelo, ca.valor HAVING COUNT(a.codaluguel) > 1;
#
# ✅ DataFrame '47' criado com sucesso! (3 linhas)
#      NomeCliente ModeloCarro  ValorCarro
# 0      Ana Silva        Polo         150
# 1  Bruna Pereira          Ka         100
# 2  Lúcia Andrade        Argo         150

# %%
'''47 - Encontre os modelos de carros que foram alugados por clientes de cidades específicas e liste as marcas desses carros.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.modelo,     m.marca FROM     carro AS c JOIN     aluguel AS a ON c.codcarro = a.codcarro JOIN     cliente AS cl ON a.codcliente = cl.codcliente JOIN     marca AS m ON c.codmarca = m.codmarca WHERE     cl.cidade IN ('São Paulo', 'Rio de Janeiro');
# Informe o nome para o DataFrame:
# 48
# SELECT     c.modelo,     m.marca FROM `omega-signifier-454016-c4.locadora.carro` AS c JOIN `omega-signifier-454016-c4.locadora.aluguel` AS a ON c.codcarro = a.codcarro JOIN `omega-signifier-454016-c4.locadora.cliente` AS cl ON a.codcliente = cl.codcliente JOIN `omega-signifier-454016-c4.locadora.marca` AS m ON c.codmarca = m.codmarca WHERE     cl.cidade IN ('São Paulo', 'Rio de Janeiro');
#
# ✅ DataFrame '48' criado com sucesso! (2 linhas)
#   modelo marca
# 0   Argo  Fiat
# 1   Argo  Fiat

# %%
'''48 - Liste os clientes que alugaram carros, os modelos e as marcas dos carros, e o total gasto em aluguéis, agrupado por cliente.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS Cliente,     ca.modelo AS ModeloCarro,     ma.marca AS MarcaCarro,     SUM(ca.valor) AS TotalGasto FROM     cliente c JOIN     aluguel a ON c.codcliente = a.codcliente JOIN     carro ca ON a.codcarro = ca.codcarro JOIN     marca ma ON ca.codmarca = ma.codmarca GROUP BY     c.nome, ca.modelo, ma.marca ORDER BY     c.nome;
# Informe o nome para o DataFrame:
# 49
# SELECT     c.nome AS Cliente,     ca.modelo AS ModeloCarro,     ma.marca AS MarcaCarro,     SUM(ca.valor) AS TotalGasto FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` ma ON ca.codmarca = ma.codmarca GROUP BY     c.nome, ca.modelo, ma.marca ORDER BY     c.nome;
#
# ✅ DataFrame '49' criado com sucesso! (7 linhas)
#             Cliente ModeloCarro  MarcaCarro  TotalGasto
# 0         Ana Silva          Ka        Ford         100
# 1         Ana Silva        Polo  Volkswagen         300
# 2     Bruna Pereira          Ka        Ford         200
# 3     Bruna Pereira        Onix   Chevrolet         170
# 4     Lúcia Andrade        Argo        Fiat         300
# 5  Túlio Nascimento          Ka        Ford         100
# 6  Túlio Nascimento        Argo        Fiat         150

# %%
'''49 - Encontre os carros que foram alugados nos últimos 30 dias e os clientes que os alugaram.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT codaluguel, data_aluguel FROM aluguel ORDER BY data_aluguel DESC;
# Informe o nome para o DataFrame:
# 50
# SELECT codaluguel, data_aluguel FROM `omega-signifier-454016-c4.locadora.aluguel` ORDER BY data_aluguel DESC;
#
# ✅ DataFrame '50' criado com sucesso! (10 linhas)
#    codaluguel data_aluguel
# 0          10   2023-04-25
# 1           9   2023-04-21
# 2           8   2023-04-19
# 3           7   2023-04-15
# 4           6   2023-04-13
# 5           5   2023-04-05
# 6           4   2023-04-04
# 7           3   2023-04-03
# 8           2   2023-04-02
# 9           1   2023-04-01

# %%
'''50 - Liste os clientes, os carros que alugaram, as marcas desses carros, e o valor total gasto em aluguéis, filtrando por um intervalo de datas específico.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT     c.nome AS NomeCliente,     ca.modelo AS ModeloCarro,     m.marca AS MarcaCarro,     SUM(ca.valor) AS ValorTotalGasto FROM     cliente c JOIN     aluguel a ON c.codcliente = a.codcliente JOIN     carro ca ON a.codcarro = ca.codcarro JOIN     marca m ON ca.codmarca = m.codmarca WHERE     a.data_aluguel BETWEEN '2023-04-01' AND '2023-04-15' GROUP BY     c.nome, ca.modelo, m.marca;
# Informe o nome para o DataFrame:
# 51
# SELECT     c.nome AS NomeCliente,     ca.modelo AS ModeloCarro,     m.marca AS MarcaCarro,     SUM(ca.valor) AS ValorTotalGasto FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro JOIN `omega-signifier-454016-c4.locadora.marca` m ON ca.codmarca = m.codmarca WHERE     a.data_aluguel BETWEEN '2023-04-01' AND '2023-04-15' GROUP BY     c.nome, ca.modelo, m.marca;
#
# ✅ DataFrame '51' criado com sucesso! (5 linhas)
#         NomeCliente ModeloCarro  MarcaCarro  ValorTotalGasto
# 0         Ana Silva          Ka        Ford              100
# 1         Ana Silva        Polo  Volkswagen              300
# 2     Bruna Pereira          Ka        Ford              200
# 3     Bruna Pereira        Onix   Chevrolet              170
# 4  Túlio Nascimento        Argo        Fiat              150

# %% [markdown]
# #Entrega do Projeto
# Criem uma sequência de consultas em um notebook.

# %%
'''1. Quantos aluguéis cada cliente fez? (Agregação + GROUP BY)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, m.marca, COUNT(a.codaluguel) AS total_alugueis   FROM aluguel a   JOIN cliente c ON a.codcliente = c.codcliente   JOIN carro ca ON a.codcarro = ca.codcarro   JOIN marca m ON ca.codmarca = m.codmarca   GROUP BY c.nome, m.marca;
# Informe o nome para o DataFrame:
# 60
# SELECT c.nome, m.marca, COUNT(a.codaluguel) AS total_alugueis   FROM `omega-signifier-454016-c4.locadora.aluguel` a   JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente   JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro   JOIN `omega-signifier-454016-c4.locadora.marca` m ON ca.codmarca = m.codmarca   GROUP BY c.nome, m.marca;
#
# ✅ DataFrame '60' criado com sucesso! (7 linhas)
#                nome       marca  total_alugueis
# 0     Bruna Pereira        Ford               2
# 1         Ana Silva        Ford               1
# 2  Túlio Nascimento        Ford               1
# 3  Túlio Nascimento        Fiat               1
# 4     Lúcia Andrade        Fiat               2
# 5     Bruna Pereira   Chevrolet               1
# 6         Ana Silva  Volkswagen               2

# %%
'''2. Quais carros foram alugados mais de 2 vezes? (GROUP BY + HAVING)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, COUNT(a.codaluguel) AS total_alugueis   FROM aluguel a   JOIN cliente c ON a.codcliente = c.codcliente   JOIN carro ca ON a.codcarro = ca.codcarro   GROUP BY c.nome;
# Informe o nome para o DataFrame:
# 61
# SELECT c.nome, COUNT(a.codaluguel) AS total_alugueis   FROM `omega-signifier-454016-c4.locadora.aluguel` a   JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente   JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro   GROUP BY c.nome;
#
# ✅ DataFrame '61' criado com sucesso! (4 linhas)
#                nome  total_alugueis
# 0     Bruna Pereira               3
# 1         Ana Silva               3
# 2  Túlio Nascimento               2
# 3     Lúcia Andrade               2

# %%
'''3.Quem são os clientes que alugaram o carro mais caro? (SUBCONSULTA + JOIN)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT DISTINCT c.nome FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente WHERE a.codcarro = (   SELECT codcarro   FROM carro   WHERE valor = (SELECT MAX(valor) FROM carro) );
# Informe o nome para o DataFrame:
# 62
# SELECT DISTINCT c.nome FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente WHERE a.codcarro = (   SELECT codcarro   FROM `omega-signifier-454016-c4.locadora.carro`   WHERE valor = (SELECT MAX(valor) FROM `omega-signifier-454016-c4.locadora.carro`) );
#
# ✅ DataFrame '62' criado com sucesso! (1 linhas)
#             nome
# 0  Bruna Pereira

# %%
'''4.Quais modelos de carros nunca foram alugados? (SUBCONSULTA NOT IN)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT modelo FROM carro WHERE codcarro NOT IN (   SELECT codcarro FROM aluguel );
# Informe o nome para o DataFrame:
# 63
# SELECT modelo FROM `omega-signifier-454016-c4.locadora.carro` WHERE codcarro NOT IN (   SELECT codcarro FROM `omega-signifier-454016-c4.locadora.aluguel` );
#
# ✅ DataFrame '63' criado com sucesso! (1 linhas)
#   modelo
# 0   Kwid

# %%
'''5.Classifique os carros como 'Econômico', 'Padrão' ou 'Premium' com base no valor. (CASE)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT modelo, valor,   CASE     WHEN valor <= 120 THEN 'Econômico'     WHEN valor <= 150 THEN 'Padrão'     ELSE 'Premium'   END AS categoria_valor FROM carro;
# Informe o nome para o DataFrame:
# 64
# SELECT modelo, valor,   CASE     WHEN valor <= 120 THEN 'Econômico'     WHEN valor <= 150 THEN 'Padrão'     ELSE 'Premium'   END AS categoria_valor FROM `omega-signifier-454016-c4.locadora.carro`;
#
# ✅ DataFrame '64' criado com sucesso! (5 linhas)
#   modelo  valor categoria_valor
# 0     Ka    100       Econômico
# 1   Kwid    120       Econômico
# 2   Argo    150          Padrão
# 3   Polo    150          Padrão
# 4   Onix    170         Premium

# %%
'''6.Crie uma CTE que retorne os clientes com mais de 2 aluguéis.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT codcliente, COUNT(*) AS total_alugueis FROM aluguel GROUP BY codcliente HAVING COUNT(*) > 2;
# Informe o nome para o DataFrame:
# 65
# SELECT codcliente, COUNT(*) AS total_alugueis FROM `omega-signifier-454016-c4.locadora.aluguel` GROUP BY codcliente HAVING COUNT(*) > 2;
#
# ✅ DataFrame '65' criado com sucesso! (2 linhas)
#    codcliente  total_alugueis
# 0           2               3
# 1           1               3

# %%
'''7.Crie uma VIEW chamada vw_resumo_alugueis com nome do cliente, modelo do carro e data do aluguel.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT      c.nome AS nome_cliente,     ca.modelo AS modelo_carro,     a.data_aluguel AS data_aluguel FROM      cliente c JOIN      aluguel a ON c.codcliente = a.codcliente JOIN      carro ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 66
# SELECT      c.nome AS nome_cliente,     ca.modelo AS modelo_carro,     a.data_aluguel AS data_aluguel FROM `omega-signifier-454016-c4.locadora.cliente` c JOIN `omega-signifier-454016-c4.locadora.aluguel` a ON c.codcliente = a.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '66' criado com sucesso! (10 linhas)
#        nome_cliente modelo_carro data_aluguel
# 0     Bruna Pereira           Ka   2023-04-02
# 1     Bruna Pereira           Ka   2023-04-03
# 2         Ana Silva           Ka   2023-04-15
# 3  Túlio Nascimento           Ka   2023-04-25
# 4  Túlio Nascimento         Argo   2023-04-01
# 5     Lúcia Andrade         Argo   2023-04-19
# 6     Lúcia Andrade         Argo   2023-04-21
# 7     Bruna Pereira         Onix   2023-04-04
# 8         Ana Silva         Polo   2023-04-05
# 9         Ana Silva         Polo   2023-04-13

# %%
'''8.Use a vw_resumo_alugueis para consultar todos os aluguéis feitos por 'Ana Silva'.'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT * FROM aluguel WHERE codcliente IN (SELECT codcliente FROM cliente WHERE nome = 'Ana Silva');
# Informe o nome para o DataFrame:
# 67
# SELECT * FROM `omega-signifier-454016-c4.locadora.aluguel` WHERE codcliente IN (SELECT codcliente FROM `omega-signifier-454016-c4.locadora.cliente` WHERE nome = 'Ana Silva');
#
# ✅ DataFrame '67' criado com sucesso! (3 linhas)
#    codaluguel  codcliente  codcarro data_aluguel
# 0           7           1         1   2023-04-15
# 1           5           1         4   2023-04-05
# 2           6           1         4   2023-04-13

# %%
'''9.Mostre a média de valor dos carros alugados por cliente. (JOIN + GROUP BY + AVG)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT c.nome, ca.modelo, a.data_aluguel FROM aluguel a JOIN cliente c ON a.codcliente = c.codcliente JOIN carro ca ON a.codcarro = ca.codcarro;
# Informe o nome para o DataFrame:
# 68
# SELECT c.nome, ca.modelo, a.data_aluguel FROM `omega-signifier-454016-c4.locadora.aluguel` a JOIN `omega-signifier-454016-c4.locadora.cliente` c ON a.codcliente = c.codcliente JOIN `omega-signifier-454016-c4.locadora.carro` ca ON a.codcarro = ca.codcarro;
#
# ✅ DataFrame '68' criado com sucesso! (10 linhas)
#                nome modelo data_aluguel
# 0     Bruna Pereira     Ka   2023-04-02
# 1     Bruna Pereira     Ka   2023-04-03
# 2         Ana Silva     Ka   2023-04-15
# 3  Túlio Nascimento     Ka   2023-04-25
# 4  Túlio Nascimento   Argo   2023-04-01
# 5     Lúcia Andrade   Argo   2023-04-19
# 6     Lúcia Andrade   Argo   2023-04-21
# 7     Bruna Pereira   Onix   2023-04-04
# 8         Ana Silva   Polo   2023-04-05
# 9         Ana Silva   Polo   2023-04-13

# %%
'''10.Encontre a cidade com o maior número de clientes. (GROUP BY + ORDER BY + LIMIT)'''
consulta()
# Out:
# Digite sua query (sem project_id.dataset):
# SELECT estado, COUNT(codcliente) AS total_clientes FROM cliente GROUP BY estado;
# Informe o nome para o DataFrame:
# 69
# SELECT estado, COUNT(codcliente) AS total_clientes FROM `omega-signifier-454016-c4.locadora.cliente` GROUP BY estado;
#
# ✅ DataFrame '69' criado com sucesso! (2 linhas)
#   estado  total_clientes
# 0     RJ               3
# 1     SP               2
