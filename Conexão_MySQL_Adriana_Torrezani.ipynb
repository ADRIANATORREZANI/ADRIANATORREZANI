# %% [markdown]
# <a href="https://colab.research.google.com/github/ADRIANATORREZANI/ADRIANATORREZANI/blob/main/Conex%C3%A3o_MySQL_Adriana_Torrezani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl ipecho.net/plain
# Out:
# 34.125.19.115

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.11/dist-packages (9.2.0)

# %%
import mysql.connector
import pandas as pd

# %%
#Definindo os parâmetros para conexão SQL
host = '35.232.61.82'
user = 'root'
password = ''
database = 'locadora'

# %% [markdown]
# #DDL

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show databases;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
bancos = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(bancos) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     798             self.sock.settimeout(self._connection_timeout)
# --> 799             self.sock.connect(sockaddr)
#     800         except (socket.timeout, TimeoutError) as err:
#
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectionTimeoutError                    Traceback (most recent call last)
# <ipython-input-18-bef7065ee66a> in <cell line: 0>()
# ----> 1 connection = mysql.connector.connect(
#       2     host=host,
#       3     user=user,
#       4     password=password,
#       5 ) # estas linhas servem para criar a conexão com o banco de dados
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     321     if CMySQLConnection and not use_pure:
#     322         return CMySQLConnection(*args, **kwargs)
# --> 323     return MySQLConnection(*args, **kwargs)
#     324
#     325
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/connection.py in __init__(self, **kwargs)
#     182         if kwargs:
#     183             try:
# --> 184                 self.connect(**kwargs)
#     185             except Exception:
#     186                 # Tidy-up underlying socket on failure
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#    1527
#    1528         self.disconnect()
# -> 1529         self._open_connection()
#    1530
#    1531         charset, collation = (
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/connection.py in _open_connection(self)
#     408                     msg=err.msg,
#     409                 ) from err
# --> 410             raise err
#     411         finally:
#     412             # as the connection is established, set back the read
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/connection.py in _open_connection(self)
#     379         self._socket = self._get_connection()
#     380         try:
# --> 381             self._socket.open_connection()
#     382
#     383             # do initial handshake
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     799             self.sock.connect(sockaddr)
#     800         except (socket.timeout, TimeoutError) as err:
# --> 801             raise ConnectionTimeoutError(
#     802                 errno=2003,
#     803                 values=(
#
# ConnectionTimeoutError: 2003: Can't connect to MySQL server on '34.125.19.115:3306' (Errno 110: Connection timed out)

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = 'create database locadora' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show databases;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
bancos = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(bancos) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#              Database
# 0  information_schema
# 1            locadora
# 2               mysql
# 3  performance_schema
# 4                 sys

# %%
# Definindo os parâmetros para conexão com a instância SQL
host = '35.232.61.82'
user = 'root'
password = ''
database = 'locadora'

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database = database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show tables;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
bancos = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(bancos) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
# Empty DataFrame
# Columns: [Tables_in_locadora]
# Index: []

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
CREATE TABLE cliente(
codcliente INT PRIMARY KEY,
nome VARCHAR(50),
cidade VARCHAR(50),
sexo CHAR(1),
estado CHAR(2),
estadocivil CHAR(1));
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
CREATE TABLE marca(
codmarca INT PRIMARY KEY,
marca VARCHAR(30)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
CREATE TABLE carro(
codcarro INT PRIMARY KEY,
codmarca INT,
modelo VARCHAR(30) NOT NULL,
valor FLOAT,
FOREIGN KEY (codmarca) REFERENCES marca (codmarca)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
CREATE TABLE aluguel(
codaluguel INT PRIMARY KEY,
codcliente INT,
codcarro INT,
data_aluguel DATE,
FOREIGN KEY (codcliente) REFERENCES cliente (codcliente),
FOREIGN KEY (codcarro) REFERENCES carro (codcarro)
);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database = database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'show tables;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
bancos = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(bancos) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#   Tables_in_locadora
# 0            aluguel
# 1              carro
# 2            cliente
# 3              marca

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
INSERT INTO cliente (codcliente, nome, cidade, sexo, estado, estadocivil)
VALUES
(1, 'Ana Silva', 'Duque de Caxias', 'F', 'RJ', 'C'),
(2, 'Bruna Pereira', 'Niterói', 'F', 'RJ', 'C'),
(3, 'Túlio Nascimento', 'Duque de Caxias', 'M', 'RJ', 'S'),
(4, 'Fernando Souza', 'Campinas', 'M', 'SP', 'S'),
(5, 'Lúcia Andrade', 'São Paulo', 'F', 'SP', 'C');
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
INSERT INTO marca (codmarca, marca) VALUES
(1, 'Ford'),
(2, 'Fiat'),
(3, 'Chevrolet'),
(4, 'Volkswagen'),
(5, 'Renault');
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
INSERT INTO carro (codcarro, modelo, codmarca, valor) VALUES
(1, 'Ka', 1, 100.00),
(2, 'Argo', 2, 150.00),
(3, 'Onix', 3, 170.00),
(4, 'Polo', 4, 150.00),
(5, 'Kwid', 5, 120.00);
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database=database,
) # estas linhas servem para criar a conexão com a instância
cursor = connection.cursor() #criando o cursor para apontar para a instância
query = '''
INSERT INTO aluguel (codaluguel, codcliente, codcarro, data_aluguel)VALUES
(1, 3, 2, '2023-04-01'),
(2, 2, 1, '2023-04-02'),
(3, 2, 1, '2023-04-03'),
(4, 2, 3, '2023-04-04'),
(5, 1, 4, '2023-04-05'),
(6, 1, 4, '2023-04-13'),
(7, 1, 1, '2023-04-15'),
(8, 5, 2, '2023-04-19'),
(9, 5, 2, '2023-04-21'),
(10,3, 1, '2023-04-25');
''' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
connection.commit()
cursor.close() # fechando o cursor
connection.close() # fechando a conexão

# %%
# Recuperando os valores da tabela cliente
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database = database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'select * from cliente;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
clientes = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(clientes) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %%
# Recuperando os valores da tabela carro
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database = database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'select * from carro;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
carro = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(carro) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0

# %%
# Recuperando os valores da tabela carro
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database = database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'select * from marca;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
marca = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(marca) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

# %%
# Recuperando os valores da tabela carro
connection = mysql.connector.connect(
    host=host,
    user=user,
    password=password,
    database = database,
) # estas linhas servem para criar a conexão com o banco de dados
cursor = connection.cursor() #criando o cursor para apontar para o banco de dados
query = 'select * from aluguel;' # Query ou consulta desejada
cursor.execute(query) # Execução da consulta
result = cursor.fetchall() # armazenando os resultados na variável results
aluguel = pd.DataFrame(result,columns=cursor.column_names) # convertendo a variável result em um df pandas chamado tabelas
display(aluguel) # exibindo a tabela pandas
cursor.close() # fechando o cursor
connection.close() # fechando a conexão
# Out:
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25

# %%
def consulta():
    # Conectando ao banco de dados
    config = {
    'host': '35.232.61.82',
    'user': 'root',
    'password': '',
    'database': 'locadora',
    'port': 3306
    }
    conn = mysql.connector.connect(**config)
    cursor = conn.cursor()

    # Recebendo a query e executando
    query = input('Insira o código SQL para a consulta desejada: ')
    cursor.execute(query)
    result = cursor.fetchall()

    # Nome do DataFrame escolhido pelo usuário
    nome_df = input("Digite o nome que deseja dar ao DataFrame: ")

    # Criando o DataFrame com nome dinâmico no escopo global
    globals()[nome_df] = pd.DataFrame(result, columns=cursor.column_names)

    # Fechando conexões
    cursor.close()
    conn.close()

    return globals()[nome_df]

# %% [markdown]
# #Fazendo Consultas ao Banco em Produção

# %%
def consulta():
    # Conectando ao banco de dados
    config = {
    'host': '35.232.61.82',
    'user': 'root',
    'password': '',
    'database': 'locadora',
    'port': 3306
    } # neste bloco todos os dados são da instância da GCP
    conn = mysql.connector.connect(**config)
    cursor = conn.cursor()

    # Recebendo a query e executando
    query = input('Insira o código SQL para a consulta desejada: ')
    cursor.execute(query)
    result = cursor.fetchall()

    # Nome do DataFrame escolhido pelo usuário
    nome_df = input("Digite o nome que deseja dar ao DataFrame: ")

    # Criando o DataFrame com nome dinâmico no escopo global
    globals()[nome_df] = pd.DataFrame(result, columns=cursor.column_names)

    # Fechando conexões
    cursor.close()
    conn.close()

    return globals()[nome_df]

# %%
'''
Recupere todas as informações da tabela cliente e armazene em
um objeto pandas chamado clientes

Código SQL da consulta: SELECT * FROM cliente;

nome do objeto a ser armazenado: clientes
'''

consulta()
# Out:
# Insira o código SQL para a consulta desejada: SELECT * FROM cliente;
# Digite o nome que deseja dar ao DataFrame:  clientes
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %%
'''
Recupere todas as informações da tabela marca e armazene em
um objeto pandas chamado marcas

Código SQL da consulta: SELECT * FROM marca;

nome do objeto a ser armazenado: marcas
'''

consulta()
# Out:
# Insira o código SQL para a consulta desejada: SELECT * FROM marca;
# Digite o nome que deseja dar ao DataFrame: marcas
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

# %%
'''
Recupere todas as informações da tabela carro e armazene em
um objeto pandas chamado carros

Código SQL da consulta: SELECT * FROM marca;

nome do objeto a ser armazenado: CARROS
'''

consulta()
# Out:
# Insira o código SQL para a consulta desejada: SELECT * FROM marca;
# Digite o nome que deseja dar ao DataFrame: carro
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

# %%
'''
Recupere todas as informações da tabela aluguel e armazene em
um objeto pandas chamado alugueis

Código SQL da consulta: SELECT * FROM marca;

nome do objeto a ser armazenado: ALUGUEIS
'''

consulta()
# Out:
# Insira o código SQL para a consulta desejada: SELECT * FROM marca;
# Digite o nome que deseja dar ao DataFrame: aluguel
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

# %% [markdown]
# #SCHEMA

# %%
consulta()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17cad0abd076> in <cell line: 0>()
# ----> 1 consulta()
#
# NameError: name 'consulta' is not defined

# %%
consulta()
# Out:
# Insira o código SQL para a consulta desejada: DESC marca
# Digite o nome que deseja dar ao DataFrame: estrutura_marca
#       Field         Type Null  Key Default Extra
# 0  codmarca          int   NO  PRI    None
# 1     marca  varchar(30)  YES         None

# %%
consulta()
# Out:
# Insira o código SQL para a consulta desejada: DESC carro
# Digite o nome que deseja dar ao DataFrame: estrutura_carro
#       Field         Type Null  Key Default Extra
# 0  codcarro          int   NO  PRI    None
# 1  codmarca          int  YES  MUL    None
# 2    modelo  varchar(30)   NO         None
# 3     valor        float  YES         None

# %%
consulta()
# Out:
# Insira o código SQL para a consulta desejada: DESC aluguel
# Digite o nome que deseja dar ao DataFrame: estrutura aluguel
#           Field  Type Null  Key Default Extra
# 0    codaluguel   int   NO  PRI    None
# 1    codcliente   int  YES  MUL    None
# 2      codcarro   int  YES  MUL    None
# 3  data_aluguel  date  YES         None

# %% [markdown]
# #SELECT

# %%
'''
A cláusula SELECT em SQL é usada para consultar dados em um banco de dados
relacional. Ela permite especificar quais colunas você deseja ver em uma
tabela ou conjunto de tabelas. É a cláusula mais usada em SQL e o ponto de
partida para qualquer consulta.

Sintaxe: SELECT, colunas_desejadas FROM nome_da_tabela_consultadas

Explicando cada parte:
SELECT: Indica que você está fazendo uma seleção de dados.
coluna1, coluna2, ...: São os nomes das colunas que você quer exibir.
FROM: Especifica de qual tabela esses dados devem ser extraídos.
'''
# Out:
# '\nA cláusula SELECT em SQL é usada para consultar dados em um banco de dados\nrelacional. Ela permite especificar quais colunas você deseja ver em uma\ntabela ou conjunto de tabelas. É a cláusula mais usada em SQL e o ponto de\npartida para qualquer consulta.\n\nSintaxe: SELECT, colunas_desejadas FROM nome_da_tabela_consultadas\n\nExplicando cada parte:\nSELECT: Indica que você está fazendo uma seleção de dados.\ncoluna1, coluna2, ...: São os nomes das colunas que você quer exibir.\nFROM: Especifica de qual tabela esses dados devem ser extraídos.\n'

# %%
'''
1. Liste todos os nomes dos clientes cadastrados.

SELECT nome FROM cliente;

'''
consulta()
