# %% [markdown]
# <a href="https://colab.research.google.com/github/ADRIANATORREZANI/ADRIANATORREZANI/blob/main/Exerc%C3%ADcios_Gr%C3%A1fico_Adriana_Torrezani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Gráfico

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
display(df)
# Out:
#    idade escolaridade     cidade
# 0     35     Superior  São Paulo
# 1     29     Superior    Atibaia
# 2     38          MBA     Santos
# 3     36     Mestrado   Bragança
# 4     28     Superior    Extrema
# 5     29     Superior    Itapeva
# 6   3029          MBA    Atibaia
# 7     30     Superior    Atibaia
# 8     40     Superior    Extrema

# %%
df['idade'].mean()
# Out:
# 366.0

# %%
df['idade'].median()
# Out:
# 35.0

# %%
# @title Cidades
import matplotlib.pyplot as plt
import seaborn as sns

# Definir a paleta de cores
palette = sns.color_palette('Dark2')
df.groupby('cidade').size().plot(kind='barh', color=palette)
plt.gca().spines[['top', 'right']].set_visible(False)
plt.title('Distribuição por Cidade')
plt.xlabel('Quantidade')
plt.ylabel('Cidade')
plt.show()

# %%
# @title Escolaridade
import matplotlib.pyplot as plt
import seaborn as sns
palette = sns.color_palette('Dark2')
df.groupby('escolaridade').size().plot(kind='barh', color=palette)
plt.gca().spines[['top', 'right']].set_visible(False)
plt.title('Distribuição por Escolaridade')
plt.xlabel('Quantidade')
plt.ylabel('Escolaridade')
plt.show()

# %%
# @title Idade
plt.pie(df['idade'].value_counts(),labels=df['idade'].unique(),autopct='%1.1f%%')
plt.title('Idade')
plt.show()

# %% [markdown]
# Perfil dos Funcionários
#
# 1. Distribuição por Cidade
# Os dados coletados mostram uma diversidade geográfica interessante. A cidade de Atibaia lidera em número de entrevistados, seguida por Extrema. Outras cidades como Itapeva, Santos, Bragança e São Paulo também estão representadas, sugerindo que o comércio local pode ter um impacto regional, atraindo profissionais de diferentes localidades.
#
# 2. Escolaridade dos Entrevistados
# A maior parte dos entrevistados possui nível superior, indicando uma força de trabalho qualificada e com potencial de especialização. Além disso, há um grupo significativo com MBA e Mestrado, o que sugere um perfil profissional avançado, possivelmente com atuação em cargos de gestão ou áreas estratégicas do comércio local.
#
# 3. Faixa Etária
# A distribuição etária está bem equilibrada, com idades variando entre 28 e 40 anos. O maior grupo dentro da amostra tem 35 anos, representando 22,2% dos participantes. Esse dado pode indicar que o comércio local atrai profissionais em um estágio intermediário da carreira, que já possuem experiência consolidada e buscam crescimento no setor.
#
# Conclusão
# Os dados indicam que o comércio local conta com profissionais altamente qualificados, provenientes de diferentes cidades e distribuídos entre diversas faixas etárias. Essa diversidade pode representar tanto desafios quanto oportunidades, permitindo que o setor se beneficie de diferentes perspectivas e níveis de experiência.
#
# Essas informações podem ser úteis para empresários locais que buscam compreender melhor o perfil dos trabalhadores e, assim, desenvolver estratégias mais eficazes para engajamento, capacitação e retenção de talentos.
