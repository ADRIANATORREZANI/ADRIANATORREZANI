# %% [markdown]
# <a href="https://colab.research.google.com/github/ADRIANATORREZANI/ADRIANATORREZANI/blob/main/Projeto_02_Adriana_Torrezani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as sp
import pandas as pd
import numpy as np

# %%
dp = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRhB33ZJJlrTseGYZJUczJRtdJswl-apzXVMRQ_IfXU_Z9fXiIYZzaoBIUoGStFT8zPy4G3h2qQDzvr/pub?output=csv')
pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRhB33ZJJlrTseGYZJUczJRtdJswl-apzXVMRQ_IfXU_Z9fXiIYZzaoBIUoGStFT8zPy4G3h2qQDzvr/pub?output=csv')
# Out:
#    Período ref. Alemanha  Itália Holanda Polônia  Suécia
# 0       jan./20   -0,57%   0,10%  -0,78%   0,91%  -1,44%
# 1       fev./20    0,30%  -0,10%   0,63%   0,68%   0,50%
# 2       mar./20    0,20%   0,10%   0,20%   0,22%  -0,17%
# 3       abr./20    0,10%   0,10%   0,46%  -0,07%  -0,30%
# 4       mai./20    0,00%  -0,19%  -0,15%  -0,22%   0,60%
# 5       jun./20    0,10%   0,10%   0,31%   0,60%   0,58%
# 6       jul./20   -0,80%  -0,19%   1,10%  -0,22%   0,22%
# 7       ago./20    0,00%   0,29%  -0,52%  -0,07%  -0,15%
# 8       set./20    0,00%  -0,68%  -0,23%   0,22%   0,06%
# 9       out./20    0,20%   0,20%   0,55%   0,07%  -0,09%
# 10      nov./20   -0,20%  -0,10%  -0,79%   0,07%   0,01%
# 11      dez./20    0,10%   0,20%   0,22%   0,07%   0,69%
# 12      jan./21    1,20%   0,68%  -0,21%   0,91%  -1,44%
# 13      fev./21    0,59%   0,10%   0,88%   0,68%   0,50%
# 14      mar./21    0,49%   0,29%   0,28%   0,22%  -0,17%
# ...

# %%
data = {
    'Período ref.': ['jan/20', 'fev/20', 'mar/20', 'abr/20', 'mai/20', 'jun/20', 'jul/20', 'ago/20', 'set/20', 'out/20', 'nov/20', 'dez/20',
                     'jan/21', 'fev/21', 'mar/21', 'abr/21', 'mai/21', 'jun/21', 'jul/21', 'ago/21', 'set/21', 'out/21', 'nov/21', 'dez/21',
                     'jan/22', 'fev/22', 'mar/22', 'abr/22', 'mai/22', 'jun/22', 'jul/22', 'ago/22', 'set/22', 'out/22', 'nov/22', 'dez/22'],
    'Alemanha': [-0.57, 0.30, 0.20, 0.10, 0.00, 0.10, -0.80, 0.00, 0.00, 0.20, -0.20, 0.10, 1.20, 0.59, 0.49, 0.29, 0.20, 0.29, 0.49, 0.10, 0.29, 0.48, 0.19, 0.19, 0.48, 0.76, 1.98, 0.65, 0.92, 0.00, 0.46, 0.36, 1.81, 0.71, 0.18, -0.44],
    'Itália': [0.10, -0.10, 0.10, 0.10, -0.19, 0.10, -0.19, 0.29, -0.68, 0.20, -0.10, 0.20, 0.68, 0.10, 0.29, 0.39, 0.00, 0.10, 0.48, 0.38, -0.19, 0.67, 0.57, 0.38, 1.59, 0.92, 1.01, -0.09, 0.82, 1.17, 0.44, 0.80, 0.26, 3.42, 0.51, 0.25],
    'Holanda': [-0.78, 0.63, 0.20, 0.46, -0.15, 0.31, 1.10, -0.52, -0.23, 0.55, -0.79, 0.22, -0.21, 0.88, 0.28, 0.45, 0.09, 0.19, 0.51, 0.44, 0.07, 1.25, 0.88, 0.74, 0.46, 0.65, 3.63, 0.29, -0.63, 0.00, 2.12, 1.96, 2.37, 1.07, -3.04, 0.47],
    'Polônia': [0.91, 0.68, 0.22, -0.07, -0.22, 0.60, -0.22, -0.07, 0.22, 0.07, 0.07, 0.07, 0.91, 0.68, 0.22, -0.07, -0.22, 0.60, -0.22, -0.07, 0.22, 0.07, 0.07, 0.07, 1.26, 0.51, 1.02, 0.79, 0.29, 0.07, 0.43, 0.28, 0.71, 1.13, 0.97, 0.90],
    'Suécia': [-1.44, 0.50, -0.17, -0.30, 0.60, 0.58, 0.22, -0.15, 0.06, -0.09, 0.01, 0.69, -1.44, 0.50, -0.17, -0.30, 0.60, 0.58, 0.22, -0.15, 0.06, -0.09, 0.01, 0.69, -0.37, 0.27, 0.16, 0.24, 0.20, 0.08, 0.27, 0.51, 0.51, 0.20, 0.46, 1.28]
}
df = pd.DataFrame(data)
medias = df[['Alemanha', 'Itália', 'Holanda', 'Polônia', 'Suécia']].mean()
print("Média da inflação por país (%):")
print(medias)
# Out:
# Média da inflação por país (%):
# Alemanha    0.336111
# Itália      0.410556
# Holanda     0.442222
# Polônia     0.357778
# Suécia      0.134167
# dtype: float64

# %%
data = {
    'Período ref.': ['jan/20', 'fev/20', 'mar/20', 'abr/20', 'mai/20', 'jun/20', 'jul/20', 'ago/20', 'set/20', 'out/20', 'nov/20', 'dez/20',
                     'jan/21', 'fev/21', 'mar/21', 'abr/21', 'mai/21', 'jun/21', 'jul/21', 'ago/21', 'set/21', 'out/21', 'nov/21', 'dez/21',
                     'jan/22', 'fev/22', 'mar/22', 'abr/22', 'mai/22', 'jun/22', 'jul/22', 'ago/22', 'set/22', 'out/22', 'nov/22', 'dez/22'],
    'Alemanha': [-0.57, 0.30, 0.20, 0.10, 0.00, 0.10, -0.80, 0.00, 0.00, 0.20, -0.20, 0.10, 1.20, 0.59, 0.49, 0.29, 0.20, 0.29, 0.49, 0.10, 0.29, 0.48, 0.19, 0.19, 0.48, 0.76, 1.98, 0.65, 0.92, 0.00, 0.46, 0.36, 1.81, 0.71, 0.18, -0.44],
    'Itália': [0.10, -0.10, 0.10, 0.10, -0.19, 0.10, -0.19, 0.29, -0.68, 0.20, -0.10, 0.20, 0.68, 0.10, 0.29, 0.39, 0.00, 0.10, 0.48, 0.38, -0.19, 0.67, 0.57, 0.38, 1.59, 0.92, 1.01, -0.09, 0.82, 1.17, 0.44, 0.80, 0.26, 3.42, 0.51, 0.25],
    'Holanda': [-0.78, 0.63, 0.20, 0.46, -0.15, 0.31, 1.10, -0.52, -0.23, 0.55, -0.79, 0.22, -0.21, 0.88, 0.28, 0.45, 0.09, 0.19, 0.51, 0.44, 0.07, 1.25, 0.88, 0.74, 0.46, 0.65, 3.63, 0.29, -0.63, 0.00, 2.12, 1.96, 2.37, 1.07, -3.04, 0.47],
    'Polônia': [0.91, 0.68, 0.22, -0.07, -0.22, 0.60, -0.22, -0.07, 0.22, 0.07, 0.07, 0.07, 0.91, 0.68, 0.22, -0.07, -0.22, 0.60, -0.22, -0.07, 0.22, 0.07, 0.07, 0.07, 1.26, 0.51, 1.02, 0.79, 0.29, 0.07, 0.43, 0.28, 0.71, 1.13, 0.97, 0.90],
    'Suécia': [-1.44, 0.50, -0.17, -0.30, 0.60, 0.58, 0.22, -0.15, 0.06, -0.09, 0.01, 0.69, -1.44, 0.50, -0.17, -0.30, 0.60, 0.58, 0.22, -0.15, 0.06, -0.09, 0.01, 0.69, -0.37, 0.27, 0.16, 0.24, 0.20, 0.08, 0.27, 0.51, 0.51, 0.20, 0.46, 1.28]
}
df = pd.DataFrame(data)
nivel_significancia = float(input("Digite o valor da significância (exemplo: 0.05 para 5%): "))
paises = ['Alemanha', 'Itália', 'Holanda', 'Polônia', 'Suécia']
print("\nMédias e variâncias da inflação por país:")
for pais in paises:
    media = df[pais].mean()
    variancia = df[pais].var()
    print(f"{pais}: Média = {media:.4f}%, Variância = {variancia:.4f}")
resultados = []
for i in range(len(paises)):
    for j in range(i + 1, len(paises)):
        pais1 = paises[i]
        pais2 = paises[j]
        t_stat, p_value = ttest_ind(df[pais1], df[pais2], nan_policy='omit')
        resultados.append((pais1, pais2, t_stat, p_value))
print("\nResultados do teste t para cada par de países:")
for pais1, pais2, t_stat, p_value in resultados:
    print(f"{pais1} vs {pais2}: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")
    if p_value < nivel_significancia:
        print(f"Com {nivel_significancia*100:.1f}% de significância, a diferença entre as médias é estatisticamente significativa.\n")
    else:
        print(f"Com {nivel_significancia*100:.1f}% de significância, não podemos afirmar que há diferença significativa entre as médias.\n")
# Out:
# Digite o valor da significância (exemplo: 0.05 para 5%): 0.05
#
# Médias e variâncias da inflação por país:
# Alemanha: Média = 0.3361%, Variância = 0.2959
# Itália: Média = 0.4106%, Variância = 0.4601
# Holanda: Média = 0.4422%, Variância = 1.1481
# Polônia: Média = 0.3578%, Variância = 0.1864
# Suécia: Média = 0.1342%, Variância = 0.2734
#
# Resultados do teste t para cada par de países:
# Alemanha vs Itália: t-statistic = -0.5137, p-value = 0.6091
# Com 5.0% de significância, não podemos afirmar que há diferença significativa entre as médias.
#
# Alemanha vs Holanda: t-statistic = -0.5298, p-value = 0.5979
# Com 5.0% de significância, não podemos afirmar que há diferença significativa entre as médias.
#
# Alemanha vs Polônia: t-statistic = -0.1872, p-value = 0.8521
# Com 5.0% de significância, não podemos afirmar que há diferença significativa entre as médias.
#
# Alemanha vs Suécia: t-statistic = 1.6059, p-value = 0.1128
# ...

# %%
medias = {
    "Alemanha": 0.336111,
    "Itália":  0.410556,
    "Holanda":  0.442222,
    "Polônia":  0.357778,
    "Suécia": 0.134167
}
for pais, media in medias.items():
    print(f"{pais}: {media:.2f}%")
# Out:
# Alemanha: 0.34%
# Itália: 0.41%
# Holanda: 0.44%
# Polônia: 0.36%
# Suécia: 0.13%

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Criando o DataFrame com os dados fornecidos
dados = {
    "Período": [
        "jan./20", "fev./20", "mar./20", "abr./20", "mai./20", "jun./20", "jul./20", "ago./20", "set./20", "out./20", "nov./20", "dez./20",
        "jan./21", "fev./21", "mar./21", "abr./21", "mai./21", "jun./21", "jul./21", "ago./21", "set./21", "out./21", "nov./21", "dez./21",
        "jan./22", "fev./22", "mar./22", "abr./22", "mai./22", "jun./22", "jul./22", "ago./22", "set./22", "out./22", "nov./22", "dez./22"
    ],
    "Alemanha": [-0.57, 0.30, 0.20, 0.10, 0.00, 0.10, -0.80, 0.00, 0.00, 0.20, -0.20, 0.10,
                 1.20, 0.59, 0.49, 0.29, 0.20, 0.29, 0.49, 0.10, 0.29, 0.48, 0.19, 0.19,
                 0.48, 0.76, 1.98, 0.65, 0.92, 0.00, 0.46, 0.36, 1.81, 0.71, 0.18, -0.44],
    "Itália": [0.10, -0.10, 0.10, 0.10, -0.19, 0.10, -0.19, 0.29, -0.68, 0.20, -0.10, 0.20,
               0.68, 0.10, 0.29, 0.39, 0.00, 0.10, 0.48, 0.38, -0.19, 0.67, 0.57, 0.38,
               1.59, 0.92, 1.01, -0.09, 0.82, 1.17, 0.44, 0.80, 0.26, 3.42, 0.51, 0.25],
    "Holanda": [-0.78, 0.63, 0.20, 0.46, -0.15, 0.31, 1.10, -0.52, -0.23, 0.55, -0.79, 0.22,
                -0.21, 0.88, 0.28, 0.45, 0.09, 0.19, 0.51, 0.44, 0.07, 1.25, 0.88, 0.74,
                0.46, 0.65, 3.63, 0.29, -0.63, 0.00, 2.12, 1.96, 2.37, 1.07, -3.04, 0.47],
    "Polônia": [0.91, 0.68, 0.22, -0.07, -0.22, 0.60, -0.22, -0.07, 0.22, 0.07, 0.07, 0.07,
                0.91, 0.68, 0.22, -0.07, -0.22, 0.60, -0.22, -0.07, 0.22, 0.07, 0.07, 0.07,
                1.26, 0.51, 1.02, 0.79, 0.29, 0.07, 0.43, 0.28, 0.71, 1.13, 0.97, 0.90],
    "Suécia": [-1.44, 0.50, -0.17, -0.30, 0.60, 0.58, 0.22, -0.15, 0.06, -0.09, 0.01, 0.69,
               -1.44, 0.50, -0.17, -0.30, 0.60, 0.58, 0.22, -0.15, 0.06, -0.09, 0.01, 0.69,
               -0.37, 0.27, 0.16, 0.24, 0.20, 0.08, 0.27, 0.51, 0.51, 0.20, 0.46, 1.28]
}

df = pd.DataFrame(dados)

# Convertendo "Período" para índice
df.set_index("Período", inplace=True)

# Criando o gráfico
plt.figure(figsize=(14, 6))
for coluna in df.columns:
    plt.plot(df.index, df[coluna], marker='o', label=coluna)

plt.xticks(rotation=90)  # Rotaciona os rótulos do eixo x para melhor visualização
plt.xlabel("Período")
plt.ylabel("Variação (%)")
plt.title("Variação Percentual por País")
plt.legend()
plt.grid(True)
plt.show()
